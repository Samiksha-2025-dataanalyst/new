# %% [markdown]
# ### electronic shop data analysis

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\Shree\Desktop\data analytics\computer_prices_all.csv")

# %%
df
# Out:
#       device_type     brand               model  release_year       os  \
# 0         Desktop   Samsung   Samsung Forge XDI          2022  Windows
# 1          Laptop   Samsung     Samsung Pro KM8          2022  Windows
# 2         Desktop    Lenovo    Lenovo Strix BIE          2024    macOS
# 3         Desktop      Dell       Dell Cube AXR          2024  Windows
# 4          Laptop  Gigabyte    Gigabyte Pro IX1          2024    Linux
# ...           ...       ...                 ...           ...      ...
# 99995      Laptop      ASUS        ASUS Pro ZWL          2023  Windows
# 99996      Laptop    Lenovo  Lenovo Stealth 014          2018  Windows
# 99997      Laptop      ASUS        ASUS Zen LKD          2020  Windows
# 99998      Laptop      ASUS      ASUS Blade DH6          2020  Windows
# 99999     Desktop      Acer      Acer Think L7R          2023  Windows
#
#       form_factor cpu_brand         cpu_model  cpu_tier  cpu_cores  ...  \
# ...

# %% [markdown]
# ### Data cleaning

# %% [markdown]
# #### pandas operations:

# %%
df.head()
# Out:
#   device_type     brand              model  release_year       os form_factor  \
# 0     Desktop   Samsung  Samsung Forge XDI          2022  Windows         ATX
# 1      Laptop   Samsung    Samsung Pro KM8          2022  Windows  Mainstream
# 2     Desktop    Lenovo   Lenovo Strix BIE          2024    macOS         SFF
# 3     Desktop      Dell      Dell Cube AXR          2024  Windows         ATX
# 4      Laptop  Gigabyte   Gigabyte Pro IX1          2024    Linux      Gaming
#
#   cpu_brand         cpu_model  cpu_tier  cpu_cores  ...  resolution  \
# 0     Intel    Intel i5-11129         3         12  ...   2560x1440
# 1     Intel    Intel i7-11114         4         12  ...   1920x1080
# 2       AMD  AMD Ryzen 5 5168         2          8  ...   3440x1440
# 3       AMD  AMD Ryzen 5 7550         2          6  ...   3440x1440
# 4       AMD  AMD Ryzen 7 6230         5         16  ...   2560x1600
#
#    refresh_hz  battery_wh charger_watts psu_watts     wifi  bluetooth  \
# ...

# %%
df.tail()
# Out:
#       device_type   brand               model  release_year       os  \
# 99995      Laptop    ASUS        ASUS Pro ZWL          2023  Windows
# 99996      Laptop  Lenovo  Lenovo Stealth 014          2018  Windows
# 99997      Laptop    ASUS        ASUS Zen LKD          2020  Windows
# 99998      Laptop    ASUS      ASUS Blade DH6          2020  Windows
# 99999     Desktop    Acer      Acer Think L7R          2023  Windows
#
#       form_factor cpu_brand         cpu_model  cpu_tier  cpu_cores  ...  \
# 99995  Mainstream     Intel    Intel i7-13721         4         12  ...
# 99996   Ultrabook       AMD  AMD Ryzen 5 5117         2          8  ...
# 99997  Mainstream     Intel    Intel i5-12677         2          6  ...
# 99998  Mainstream       AMD  AMD Ryzen 7 4590         4         12  ...
# 99999         SFF     Intel    Intel i9-14345         6         26  ...
#
#        resolution  refresh_hz  battery_wh charger_watts psu_watts      wifi  \
# ...

# %%
df.size
# Out:
# 3300000

# %% [raw]
# df.shape()

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       device_type     brand               model  release_year       os  \
# 0         Desktop   Samsung   Samsung Forge XDI          2022  Windows
# 1          Laptop   Samsung     Samsung Pro KM8          2022  Windows
# 2         Desktop    Lenovo    Lenovo Strix BIE          2024    macOS
# 3         Desktop      Dell       Dell Cube AXR          2024  Windows
# 4          Laptop  Gigabyte    Gigabyte Pro IX1          2024    Linux
# ...           ...       ...                 ...           ...      ...
# 99995      Laptop      ASUS        ASUS Pro ZWL          2023  Windows
# 99996      Laptop    Lenovo  Lenovo Stealth 014          2018  Windows
# 99997      Laptop      ASUS        ASUS Zen LKD          2020  Windows
# 99998      Laptop      ASUS      ASUS Blade DH6          2020  Windows
# 99999     Desktop      Acer      Acer Think L7R          2023  Windows
#
#       form_factor cpu_brand         cpu_model  cpu_tier  cpu_cores  ...  \
# ...

# %%
df.columns
# Out:
# Index(['device_type', 'brand', 'model', 'release_year', 'os', 'form_factor',
#        'cpu_brand', 'cpu_model', 'cpu_tier', 'cpu_cores', 'cpu_threads',
#        'cpu_base_ghz', 'cpu_boost_ghz', 'gpu_brand', 'gpu_model', 'gpu_tier',
#        'vram_gb', 'ram_gb', 'storage_type', 'storage_gb',
#        'storage_drive_count', 'display_type', 'display_size_in', 'resolution',
#        'refresh_hz', 'battery_wh', 'charger_watts', 'psu_watts', 'wifi',
#        'bluetooth', 'weight_kg', 'warranty_months', 'price'],
#       dtype='object')

# %%
#check null values in data

# %%
df.isnull().sum()
# Out:
# device_type            0
# brand                  0
# model                  0
# release_year           0
# os                     0
# form_factor            0
# cpu_brand              0
# cpu_model              0
# cpu_tier               0
# cpu_cores              0
# cpu_threads            0
# cpu_base_ghz           0
# cpu_boost_ghz          0
# gpu_brand              0
# gpu_model              0
# gpu_tier               0
# vram_gb                0
# ram_gb                 0
# storage_type           0
# storage_gb             0
# storage_drive_count    0
# display_type           0
# display_size_in        0
# resolution             0
# refresh_hz             0
# battery_wh             0
# charger_watts          0
# psu_watts              0
# wifi                   0
# bluetooth              0
# weight_kg              0
# warranty_months        0
# price                  0
# dtype: int64

# %% [markdown]
# so data dosent consists of null values

# %%
#check duplicates in the data

# %%
df.drop_duplicates()
# Out:
#       device_type     brand               model  release_year       os  \
# 0         Desktop   Samsung   Samsung Forge XDI          2022  Windows
# 1          Laptop   Samsung     Samsung Pro KM8          2022  Windows
# 2         Desktop    Lenovo    Lenovo Strix BIE          2024    macOS
# 3         Desktop      Dell       Dell Cube AXR          2024  Windows
# 4          Laptop  Gigabyte    Gigabyte Pro IX1          2024    Linux
# ...           ...       ...                 ...           ...      ...
# 99995      Laptop      ASUS        ASUS Pro ZWL          2023  Windows
# 99996      Laptop    Lenovo  Lenovo Stealth 014          2018  Windows
# 99997      Laptop      ASUS        ASUS Zen LKD          2020  Windows
# 99998      Laptop      ASUS      ASUS Blade DH6          2020  Windows
# 99999     Desktop      Acer      Acer Think L7R          2023  Windows
#
#       form_factor cpu_brand         cpu_model  cpu_tier  cpu_cores  ...  \
# ...

# %% [markdown]
# data doesnot consists of duplicates

# %%
df.dtypes
# Out:
# device_type             object
# brand                   object
# model                   object
# release_year             int64
# os                      object
# form_factor             object
# cpu_brand               object
# cpu_model               object
# cpu_tier                 int64
# cpu_cores                int64
# cpu_threads              int64
# cpu_base_ghz           float64
# cpu_boost_ghz          float64
# gpu_brand               object
# gpu_model               object
# gpu_tier                 int64
# vram_gb                  int64
# ram_gb                   int64
# storage_type            object
# storage_gb               int64
# storage_drive_count      int64
# display_type            object
# display_size_in        float64
# resolution              object
# refresh_hz               int64
# battery_wh               int64
# charger_watts            int64
# psu_watts                int64
# wifi                    object
# bluetooth              float64
# ...

# %% [markdown]
# ### EDA (Exploratory Data Analysis)

# %%
plt.figure(figsize=(11,6))
a=sns.countplot(data=df, x="device_type",hue="release_year")
for i in a.containers:
    a.bar_label(i)

# %%
plt.figure(figsize=(14,5))
a=sns.countplot(data=df, x="device_type",hue="brand")
for i in a.containers:
    a.bar_label(i)
